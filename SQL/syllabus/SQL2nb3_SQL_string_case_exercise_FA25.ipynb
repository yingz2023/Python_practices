# %% [markdown]
# <a href="https://colab.research.google.com/github/yingz2023/Python_practices/blob/main/SQL/syllabus/SQL2nb3_SQL_string_case_exercise_FA25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SQL Example with STRINGs and CASEs

# %%
# !wget https://github.com/gt-cse-6040/bootcamp/raw/main/SQL/syllabus/NYC-311-2M_small.db
# Out:
# --2025-10-19 18:30:44--  https://github.com/gt-cse-6040/bootcamp/raw/main/SQL/syllabus/NYC-311-2M_small.db
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/gt-cse-6040/bootcamp/main/SQL/syllabus/NYC-311-2M_small.db [following]
# --2025-10-19 18:30:44--  https://raw.githubusercontent.com/gt-cse-6040/bootcamp/main/SQL/syllabus/NYC-311-2M_small.db
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20639744 (20M) [application/octet-stream]
# Saving to: ‘NYC-311-2M_small.db’
#
# NYC-311-2M_small.db 100%[===================>]  19.68M  --.-KB/s    in 0.06s
#
# 2025-10-19 18:30:44 (311 MB/s) - ‘NYC-311-2M_small.db’ saved [20639744/20639744]

# %%
# create a connection to the database
import sqlite3 as db
import pandas as pd

# Connect to a database (or create one if it doesn't exist)
conn_nyc = db.connect('NYC-311-2M_small.db')

# %%
df_all_data = pd.read_sql("SELECT * FROM data LIMIT 5", conn_nyc)
display(df_all_data)
# Out:
#      index                 CreatedDate                  ClosedDate Agency  \
# 0  1594705  2014-11-30 23:55:48.000000  2014-12-01 02:07:32.000000   NYPD
# 1  1594706  2014-11-30 23:54:57.000000  2014-12-01 01:12:40.000000   NYPD
# 2  1594708  2014-11-30 23:51:28.000000  2014-11-30 23:52:21.000000    HRA
# 3  1594709  2014-11-30 23:50:35.000000  2014-12-01 04:18:46.000000   NYPD
# 4  1594710  2014-11-30 23:49:07.000000  2014-12-01 01:45:30.000000   NYPD
#
#               ComplaintType       Descriptor      City
# 0   Noise - Street/Sidewalk     Loud Talking  NEW YORK
# 1   Noise - Street/Sidewalk     Loud Talking     BRONX
# 2  Benefit Card Replacement       Food Stamp      None
# 3          Blocked Driveway        No Access     BRONX
# 4           Noise - Vehicle  Car/Truck Music  NEW YORK

# %% [markdown]
# ## EX0 Example
# From the `data` table for `Agency='NYPD'`, use the column `CompliantType` to extract "`primaryComplaint` - `secondaryComplaint`":
# *  Columns
#    *  `ComplaintType`
#    *  `primaryComplaint`:
#       *  This is everything **before** a `-`
#       *  If there is no `-`, this should be the same as `ComplaintType`
#    *  `secondaryComplaint`:
#       *  This is everything **after** a `-`
#       *  If there is no `-`, this should return NULL or None

# %%
def extractcomplaints() -> str:
  return f"""
  SELECT ComplaintType
          ,CASE
              WHEN ComplaintType LIKE '% - %'
                    THEN SUBSTR(ComplaintType,1,INSTR(ComplaintType,' - ')-1)
              ELSE ComplaintType
           END primaryComplaint
          ,CASE
              WHEN ComplaintType LIKE '% - %'
                    THEN SUBSTR(ComplaintType,INSTR(ComplaintType,' - ')+3)
              ELSE NULL
           END secondaryComplaint
  FROM data
  WHERE Agency='NYPD'
  """
d=pd.read_sql(extractcomplaints(),conn_nyc)
display(d)
# d.dtypes
# Out:
#                  ComplaintType  primaryComplaint secondaryComplaint
# 0      Noise - Street/Sidewalk             Noise    Street/Sidewalk
# 1      Noise - Street/Sidewalk             Noise    Street/Sidewalk
# 2             Blocked Driveway  Blocked Driveway               None
# 3              Noise - Vehicle             Noise            Vehicle
# 4                 Noise - Park             Noise               Park
# ...                        ...               ...                ...
# 21975          Illegal Parking   Illegal Parking               None
# 21976       Noise - Commercial             Noise         Commercial
# 21977       Noise - Commercial             Noise         Commercial
# 21978       Noise - Commercial             Noise         Commercial
# 21979          Illegal Parking   Illegal Parking               None
#
# [21980 rows x 3 columns]
